# %% [markdown]
# # CDL

# %%
import numpy as np
import pickle
import tensorflow as tf
import pandas as pd
from keras.preprocessing.text import Tokenizer, one_hot
from pandas.api.types import CategoricalDtype
from scipy.sparse import csr_matrix
#init random seed
np.random.seed(5)
from sklearn.model_selection import train_test_split
import os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import mean_squared_error, mean_absolute_error
from collections import defaultdict, namedtuple
from experiment_out_utils import precision_recall_at_k_4df, write_to_csv, XPData, XPRow, write_row
import itertools as it
from model_out_utils import make_out_dirs
import mf_sgd
from imp import reload
reload(mf_sgd)
# Out:
# <module 'mf_sgd' from 'C:\\Users\\irina\\Dev\\master\\mf_sgd.py'>

# %%
### create all necessary dirs for output ###

XP_PATH, U_V_PATH, MODEL_PATH = make_out_dirs(model_name='sdae-sgd', xp_name='sdae_sgd_optimized4') 
print("Out dir of experiment: ", XP_PATH)
print("Out dir of U, V matricies: ", U_V_PATH)
print("Out dir of model parameters: ", MODEL_PATH)
# Out:
# Out dir of experiment:  D:/Models/thesis/sdae-sgd/sdae_sgd_optimized4/
# Out dir of U, V matricies:  D:/Models/thesis/sdae-sgd/sdae_sgd_optimized4/pickles/
# Out dir of model parameters:  D:/Models/thesis/sdae-sgd/sdae_sgd_optimized4/tf/

# %% [markdown]
# ## 1. Data Preprocessing

# %%
#df = pd.read_json('/home/neopux/UHH/datasets/Video_Games_5_proc.json')
df = pd.read_json(r'D:\Datasets\amazon_reviews\processed\reviews_Toys_and_Games_5.json')

# %%
df.head(2)
# Out:
#          asin helpful  overall  \
# 0  0439893577  [0, 0]        5
# 1  0439893577  [1, 1]        4
#
#                                           reviewText  \
# 0  I like the item pricing. My granddaughter want...
# 1  Love the magnet easel... great for moving to d...
#
#                                       reviewTextProc   reviewTime  \
# 0  i like item pricing my granddaughter want mark...  01 29, 2014
# 1  love magnet easel great move different area wi...  03 28, 2014
#
#        reviewerID reviewerName  \
# 0  A1VXOAVRGKGEAK        Angie
# 1   A8R62G708TSCM      Candace
#
#                                              summary  \
# 0                                     Magnetic board
# 1  it works pretty good for moving to different a...
#
#                             summaryProc  unixReviewTime
# 0                        magnetic board      1390953600
# 1  work pretty good move different area      1395964800

# %%
df_train, df_test = train_test_split(df, test_size = 0.3, stratify=df['reviewerID'], random_state=42)

# %% [markdown]
# ### Prepare Reviews

# %%
train_reviews = df_train.groupby('asin').reviewTextProc.agg(' '.join)
test_reviews = df_test.groupby('asin').reviewTextProc.agg(' '.join)

# %%
train_summaries = df_train.groupby('asin').summaryProc.agg(' '.join)
test_summaries = df_test.groupby('asin').summaryProc.agg(' '.join)

# %%
total_train_rev = train_summaries + train_reviews
total_test_rev = test_summaries + test_reviews

# %%
vectorizer = TfidfVectorizer(max_features=10000)
item_infomation_matrix = vectorizer.fit_transform(total_train_rev.values)

# %%
del total_train_rev, total_test_rev, test_summaries, train_summaries, train_reviews, test_reviews

# %%
print(item_infomation_matrix.shape)
# Out:
# (11917, 10000)

# %%
sorted(vectorizer.vocabulary_.items(), reverse=True)[5940:5960]
# Out:
# [('had', 4059),
#  ('hack', 4058),
#  ('habitat', 4057),
#  ('habit', 4056),
#  ('haba', 4055),
#  ('ha', 4054),
#  ('gyroscope', 4053),
#  ('gyro', 4052),
#  ('gymnastic', 4051),
#  ('gym', 4050),
#  ('guys', 4049),
#  ('guy', 4048),
#  ('gut', 4047),
#  ('gus', 4046),
#  ('guppy', 4045),
#  ('guppies', 4044),
#  ('guppie', 4043),
#  ('gup', 4042),
#  ('guns', 4041),
#  ('gunner', 4040)]

# %%
list(vectorizer.stop_words_)[0:10]
# Out:
# ['hourage',
#  'onebuy',
#  'haothis',
#  'zirndorf',
#  'missles',
#  'dishonesty',
#  'breeds',
#  'willlet',
#  'soother',
#  'punks']

# %%
item_infomation_matrix = np.array(item_infomation_matrix.todense())

# %% [markdown]
# ### Prepare Rating Matrix

# %%
df_train = df_train.copy()
asins_map = {v:k for k,v in enumerate(df_train['asin'].unique())}
reviewers_map = {v:k for k,v in enumerate(df_train['reviewerID'].unique())}

df_train['in_asin'] = df_train['asin'].map(asins_map)
df_train['in_revID'] = df_train['reviewerID'].map(reviewers_map)

dataset = df_train[['in_asin', 'in_revID', 'overall']]

trainset, valset = train_test_split(dataset, test_size = 0.2, stratify=dataset['in_revID'], random_state=42)

df_test = df_test.copy()
df_test['value'] = 0
df_test['in_asin'] = df_test['asin'].map(asins_map)
df_test['in_revID'] = df_test['reviewerID'].map(reviewers_map)
df_test = df_test.dropna(subset=['in_asin'])
df_test = df_test.astype({"in_asin": int})

testset = df_test[['in_asin', 'in_revID', 'overall']]

# %% [markdown]
# ## 2. Building Model

# %% [markdown]
# ### Masking Noise

# %%
def mask(corruption_level, shape):
    return np.random.binomial(1, 1 - corruption_level, shape)

def add_noise(x , corruption_level ):
    mask_ = mask(corruption_level , x.shape)
    print("Mask shape: " + str(mask_.shape))
    x = np.multiply(x, mask_)
    print("Noising completed..:" + str(x.shape))
    return x

# %% [markdown]
# ### SDAE & CDL

# %%
class CDL():
    def __init__(self , rating_matrix, valid_set, item_infomation_matrix, n_users, n_items, out_path = None, k=10, 
                 epochs=50, batch_size=32, lr=0.001, hidden_size=25, matrix_noise = 0.3,
                drop_ratio=0.1, lambda_w = 1, lambda_n = 1, lambda_v = 1, lambda_q = 0.01):
        self.out_path = out_path
        
        self.k = k
        self.n_input = item_infomation_matrix.shape[1] # dimensionality of text representations - 1000
        self.n_hidden1 = hidden_size
        self.n_hidden2 = self.k
        
        # lambdas for loss calc
        self.lambda_w = lambda_w
        self.lambda_n = lambda_n
        self.lambda_v = lambda_v
        self.lambda_q = lambda_q
        
        self.drop_ratio = drop_ratio
        self.learning_rate = lr
        self.epochs = epochs
        self.batch_size = batch_size
        
        self.num_u = n_users
        self.num_v = n_items
        
        intializer = tf.variance_scaling_initializer()
        self.non_zero_idx = rating_matrix > 0
        
        self.Weights = { 
            'w1' : tf.Variable(intializer([self.n_input, self.n_hidden1]), dtype=tf.float32),
            'w2' : tf.Variable(intializer([self.n_hidden1, self.n_hidden2]), dtype=tf.float32),
            'w3' : tf.Variable(intializer([self.n_hidden2, self.n_hidden1]), dtype=tf.float32),
            'w4' : tf.Variable(intializer([self.n_hidden1, self.n_input]), dtype=tf.float32)   
        }
        self.Biases = {
            #'b1' : tf.Variable(tf.random_normal( [self.n_hidden1] , mean=0.0, stddev=1 / self.lambda_w )),
            #'b2' : tf.Variable(tf.random_normal( [self.n_hidden2] , mean=0.0, stddev=1 / self.lambda_w )),
            #'b3' : tf.Variable(tf.random_normal( [self.n_hidden1] , mean=0.0, stddev=1 / self.lambda_w )),
            #'b4' : tf.Variable(tf.random_normal( [self.n_input] , mean=0.0, stddev=1 / self.lambda_w ))
            'b1' : tf.Variable(tf.zeros(self.n_hidden1)),
            'b2' : tf.Variable(tf.zeros(self.n_hidden2)),
            'b3' : tf.Variable(tf.zeros(self.n_hidden1)),
            'b4' : tf.Variable(tf.zeros(self.n_input))
        }
        
        self.item_infomation_matrix = item_infomation_matrix
        self.item_infomation_matrix_noise = add_noise(self.item_infomation_matrix , matrix_noise)
        self.rating_matrix = rating_matrix
        self.valid_set = valid_set
    
        self.build_model()
        self.saver = tf.train.Saver()
        
    def encoder(self , x , drop_ratio):
        w1 = self.Weights['w1']
        b1 = self.Biases['b1']
        L1 = tf.nn.relu(tf.matmul(x, w1) + b1)
        L1 = tf.nn.dropout( L1 , keep_prob= 1 - drop_ratio)
        
        w2 = self.Weights['w2']
        b2 = self.Biases['b2']
        L2 = tf.nn.relu(tf.matmul(L1, w2) + b2)
        L2 = tf.nn.dropout(L2 , keep_prob= 1 - drop_ratio)
        return L2
    
    def decoder(self , x , drop_ratio):
        w3 = self.Weights['w3']
        b3 = self.Biases['b3']
        L3 = tf.nn.relu(tf.matmul(x, w3) + b3)
        L3 = tf.nn.dropout(L3 , keep_prob= 1 - drop_ratio)

        w4 = self.Weights['w4']
        b4 = self.Biases['b4']
        L4 = tf.nn.relu(tf.matmul(L3, w4) + b4)
        L4 = tf.nn.dropout(L4 , keep_prob= 1 - drop_ratio)
        return L4
    
    def build_model(self):
        self.model_X_0 = tf.placeholder(tf.float32 , shape=(None , self.n_input))
        self.model_X_c = tf.placeholder(tf.float32 , shape=(None , self.n_input))
        
        self.model_V = tf.placeholder(tf.float32 , shape=(None , self.k))
        self.model_drop_ratio = tf.placeholder(tf.float32)
        
        self.V_sdae = self.encoder(self.model_X_0 , self.model_drop_ratio)
        self.y_pred = self.decoder(self.V_sdae , self.model_drop_ratio)
        
        self.Regularization = tf.reduce_sum([tf.nn.l2_loss(w) + tf.nn.l2_loss(b) 
                                             for w,b in zip(self.Weights.values() , self.Biases.values())])
        loss_r = 1/2 * self.lambda_w * self.Regularization
        self.loss_a = 1/2 * self.lambda_n * tf.reduce_sum(tf.pow(self.model_X_c - self.y_pred , 2))
        loss_v = 1/2 * self.lambda_v * tf.reduce_sum(tf.pow(self.model_V - self.V_sdae , 2))
        
        self.Loss = loss_r + self.loss_a + loss_v
        self.optimizer = tf.train.AdamOptimizer(self.learning_rate).minimize(self.Loss)
        
    
    def training(self):
        sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
        
        ## define dirs for tensorboard if needed
        if self.out_path != None:
            train_writer = tf.summary.FileWriter('%s/tf/train' % self.out_path, sess.graph)
            test_writer = tf.summary.FileWriter('%s/tf/test' % self.out_path, sess.graph)
            
        val_losses = []
        
        sess.run(tf.global_variables_initializer())
        mf = mf_sgd.SGD(dataset=self.rating_matrix, n_factors=self.k, 
                        n_items=self.num_v, n_users=self.num_u, 
                        lambda_q=self.lambda_q)
        
        for epoch in range(0, self.epochs):
            print("EPOCH %s / %s" % (epoch + 1, self.epochs))
            
            V_sdae = sess.run(self.V_sdae , feed_dict={self.model_X_0 : self.item_infomation_matrix_noise , 
                                                       self.model_drop_ratio : self.drop_ratio})
            # calc and print ALS loss every N epochs
            mu, pu, qi, bu, bi = mf.run_epoch(qi_cdl = V_sdae)
            err_rmse, err_mae = mf.current_error()
            
            val_loss =  mean_squared_error(self.valid_set[:, -1], mf.predict_dataset(self.valid_set)) ** 0.5
            val_losses.append(val_loss)
            
            ## stop early if during last 3 epochs error is only increasing
            if val_losses[-3:] and all(loss > val_losses[-3:][0] for loss in val_losses[-2:]):
                print('Stopping early because %s is larger than %s' % (val_losses[-3:][0], val_losses[-2:]))
                break
            
            auto_losses = []
            model_losses = []
            for i in range(0 , self.item_infomation_matrix.shape[0] , self.batch_size):
                X_train_batch = self.item_infomation_matrix_noise[i : i+self.batch_size]
                y_train_batch = self.item_infomation_matrix[i : i+self.batch_size]
                
                V_batch = qi[i : i + self.batch_size]
                _ , my_loss, auto_loss = sess.run([self.optimizer, self.Loss, self.loss_a] , 
                                       feed_dict={self.model_X_0: X_train_batch , 
                                                  self.model_X_c: y_train_batch, 
                                                  self.model_V: V_batch, 
                                                  self.model_drop_ratio : self.drop_ratio})
                auto_losses.append(auto_loss)
                model_losses.append(my_loss)
            
            print("ALS LOSS RMSE = %s, MAE = %s" % (err_rmse, err_mae)) 
            print("MODEL LOSS %s" % np.mean(model_losses))
            print("AUTOENCODER LOSS %s" % np.mean(auto_losses))  
            print("VALIDATION LOSS %s" % val_loss)
            
            # save log files
            if self.out_path != None:
                # dump summaries
                summary = tf.Summary();
                summary.value.add(tag='Autoencoder Loss', simple_value=np.mean(auto_losses))
                summary.value.add(tag='Model Loss', simple_value=np.mean(model_losses))
                summary.value.add(tag='ALS Loss', simple_value=err_rmse)
                summary.value.add(tag='Val Loss', simple_value=val_loss)
                train_writer.add_summary(summary, epoch + 1)
                # dump model and pickles
                if epoch % 5 == 0:
                    # save tensorflow model
                    self.saver.save(sess, '%s/tf/model_epoch_%s.ckpt' % (self.out_path, epoch))
                    # save matricies and biases
                    with open('%s/pickles/mx_epoch_%s.pickle' % (self.out_path, epoch), 'wb') as handle:
                        pickle.dump({'mu':mu, 'pu':pu, 'qi':qi, 'bu':bu, 'bi':bi}, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
        sess.close()
        return mu, pu, qi, bu, bi

# %%
item_infomation_matrix.shape
# Out:
# (11917, 10000)

# %%
dataset.shape
# Out:
# (117317, 3)

# %%
testset.shape
# Out:
# (50245, 3)

# %% [markdown]
# ### Training

# %%
# %reset Out
tf.reset_default_graph()
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y
# Flushing output cache (6 entries)

# %%
cdl = CDL(trainset.values, valset.values, item_infomation_matrix, n_users=len(reviewers_map), n_items=len(asins_map),
          out_path=XP_PATH, k=25, hidden_size=100, 
          matrix_noise=0.3, drop_ratio=0.1, epochs=50,
          lambda_w=1, lambda_v=1, lambda_n=10, lambda_q = 10)
mu, pu, qi, bu, bi = cdl.training() #188910
# Out:
# Mask shape: (11917, 10000)
# Noising completed..:(11917, 10000)
# EPOCH 1 / 50
# ALS LOSS RMSE = 0.9672284246053714, MAE = 0.7636993889826998
# MODEL LOSS 546.3411
# AUTOENCODER LOSS 150.94588
# VALIDATION LOSS 0.9775386104392274
# EPOCH 2 / 50
# ALS LOSS RMSE = 0.9454426783442945, MAE = 0.7424814635280944
# MODEL LOSS 152.40305
# AUTOENCODER LOSS 150.60194
# VALIDATION LOSS 0.9645576385203087
# EPOCH 3 / 50
# ALS LOSS RMSE = 0.9271677479359064, MAE = 0.72457765491275
# MODEL LOSS 151.61737
# AUTOENCODER LOSS 150.63403
# VALIDATION LOSS 0.9542944538057154
# EPOCH 4 / 50
# ALS LOSS RMSE = 0.9113937737261483, MAE = 0.7090915862235802
# MODEL LOSS 151.341
# AUTOENCODER LOSS 150.6282
# VALIDATION LOSS 0.9459461828721625
# EPOCH 5 / 50
# ALS LOSS RMSE = 0.8975303356724822, MAE = 0.695520195370166
# MODEL LOSS 151.15845
# AUTOENCODER LOSS 150.62498
# VALIDATION LOSS 0.9390390837815858
# EPOCH 6 / 50
# ALS LOSS RMSE = 0.8851820704252794, MAE = 0.6834553598856111
# MODEL LOSS 151.0142
# AUTOENCODER LOSS 150.60057
# VALIDATION LOSS 0.9332533706018639
# EPOCH 7 / 50
# ALS LOSS RMSE = 0.8740673219431416, MAE = 0.6725886400214766
# MODEL LOSS 150.94777
# AUTOENCODER LOSS 150.61874
# VALIDATION LOSS 0.9283607537121052
# EPOCH 8 / 50
# ALS LOSS RMSE = 0.863977389488637, MAE = 0.6627257190162315
# MODEL LOSS 150.85008
# AUTOENCODER LOSS 150.58281
# VALIDATION LOSS 0.9241925626853431
# EPOCH 9 / 50
# ALS LOSS RMSE = 0.8547530962150623, MAE = 0.6536895387722227
# MODEL LOSS 150.83379
# AUTOENCODER LOSS 150.61554
# VALIDATION LOSS 0.9206209751042633
# EPOCH 10 / 50
# ALS LOSS RMSE = 0.8462702198536431, MAE = 0.6453579355815966
# MODEL LOSS 150.7984
# AUTOENCODER LOSS 150.60889
# VALIDATION LOSS 0.917547126373778
# EPOCH 11 / 50
# ALS LOSS RMSE = 0.8384299478462972, MAE = 0.6376429933257014
# MODEL LOSS 150.7785
# AUTOENCODER LOSS 150.6183
# VALIDATION LOSS 0.9148932216028902
# EPOCH 12 / 50
# ALS LOSS RMSE = 0.8311523807507429, MAE = 0.6304654795097362
# MODEL LOSS 150.73642
# AUTOENCODER LOSS 150.58168
# VALIDATION LOSS 0.912597124061108
# EPOCH 13 / 50
# ALS LOSS RMSE = 0.8243719774493974, MAE = 0.623757155306725
# MODEL LOSS 150.77585
# AUTOENCODER LOSS 150.64772
# VALIDATION LOSS 0.9106085438058537
# EPOCH 14 / 50
# ALS LOSS RMSE = 0.8180342842482221, MAE = 0.6174739885092314
# MODEL LOSS 150.73097
# AUTOENCODER LOSS 150.60783
# VALIDATION LOSS 0.9088862947505653
# EPOCH 15 / 50
# ALS LOSS RMSE = 0.8120935383653725, MAE = 0.6115717495732432
# MODEL LOSS 150.73569
# AUTOENCODER LOSS 150.61984
# VALIDATION LOSS 0.9073962842051845
# EPOCH 16 / 50
# ALS LOSS RMSE = 0.8065108815431576, MAE = 0.6060218172303161
# MODEL LOSS 150.71681
# AUTOENCODER LOSS 150.61037
# VALIDATION LOSS 0.9061100156880949
# EPOCH 17 / 50
# ALS LOSS RMSE = 0.8012530081527165, MAE = 0.6007888349292227
# MODEL LOSS 150.73862
# AUTOENCODER LOSS 150.62364
# VALIDATION LOSS 0.9050034581759491
# EPOCH 18 / 50
# ALS LOSS RMSE = 0.7962911281809303, MAE = 0.5958426159469402
# MODEL LOSS 150.73706
# AUTOENCODER LOSS 150.62994
# VALIDATION LOSS 0.9040561812315604
# EPOCH 19 / 50
# ALS LOSS RMSE = 0.7916001619383742, MAE = 0.5911589423696706
# MODEL LOSS 150.72711
# AUTOENCODER LOSS 150.62538
# VALIDATION LOSS 0.9032506858228447
# EPOCH 20 / 50
# ALS LOSS RMSE = 0.7871581076301568, MAE = 0.5867238259879755
# MODEL LOSS 150.7186
# AUTOENCODER LOSS 150.60172
# VALIDATION LOSS 0.9025718810304684
# EPOCH 21 / 50
# ALS LOSS RMSE = 0.7829455394780966, MAE = 0.5825183410026854
# MODEL LOSS 150.71706
# AUTOENCODER LOSS 150.6165
# VALIDATION LOSS 0.9020066707882858
# EPOCH 22 / 50
# ALS LOSS RMSE = 0.7789452055552275, MAE = 0.5785248450703725
# MODEL LOSS 150.70918
# AUTOENCODER LOSS 150.60025
# VALIDATION LOSS 0.9015436245015078
# EPOCH 23 / 50
# ALS LOSS RMSE = 0.7751417025639035, MAE = 0.5747322648139622
# MODEL LOSS 150.73138
# AUTOENCODER LOSS 150.61766
# VALIDATION LOSS 0.9011727122556511
# EPOCH 24 / 50
# ALS LOSS RMSE = 0.771521210593812, MAE = 0.5711240105697434
# MODEL LOSS 150.7355
# AUTOENCODER LOSS 150.64156
# VALIDATION LOSS 0.900885090174619
# EPOCH 25 / 50
# ALS LOSS RMSE = 0.768071275006906, MAE = 0.5676909500140559
# MODEL LOSS 150.71938
# AUTOENCODER LOSS 150.62239
# VALIDATION LOSS 0.9006729251467962
# EPOCH 26 / 50
# ALS LOSS RMSE = 0.764780625730219, MAE = 0.5644240649608411
# MODEL LOSS 150.73619
# AUTOENCODER LOSS 150.62514
# VALIDATION LOSS 0.9005292506046539
# EPOCH 27 / 50
# ALS LOSS RMSE = 0.7616390264376671, MAE = 0.561316883766753
# MODEL LOSS 150.72632
# AUTOENCODER LOSS 150.64662
# VALIDATION LOSS 0.9004478470639372
# EPOCH 28 / 50
# ALS LOSS RMSE = 0.758637147816935, MAE = 0.558353272110266
# MODEL LOSS 150.69998
# AUTOENCODER LOSS 150.63684
# VALIDATION LOSS 0.9004231425185114
# EPOCH 29 / 50
# ALS LOSS RMSE = 0.7557661542223773, MAE = 0.5555297147132434
# MODEL LOSS 150.69823
# AUTOENCODER LOSS 150.60754
# VALIDATION LOSS 0.9004500233678213
# EPOCH 30 / 50
# Stopping early because 0.9004231425185114 is larger than [0.9004500233678213, 0.9005242143240008]

# %%
## dump U and V matricies to pickle files
print("pu shape: %s x %s" % pu.shape)
print("qi shape: %s x %s" % qi.shape)

print("beta_u shape: %s" % bu.shape)
print("beta_i shape: %s" % bi.shape)

with open(U_V_PATH + 'mx.pickle', 'wb') as handle:
    pickle.dump({'mu':mu, 'pu':pu, 'qi':qi, 'bu':bu, 'bi':bi}, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# pu shape: 19412 x 25
# qi shape: 11917 x 25
# beta_u shape: 19412
# beta_i shape: 11917

# %% [markdown]
# ## Evaluation

# %%
test_preds = mf_sgd.SGD.predict_dataset_with_params(testset.values, mu, bu, bi, qi, pu)

# %%
df_test['value'] = test_preds

# %%
mse = mean_squared_error(df_test.overall, df_test.value) ** 0.5
mae = mean_absolute_error(df_test.overall, df_test.value)

print("MSE: %s" % mse)
print("MAE: %s" % mae)
# Out:
# MSE: 0.9024861162977229
# MAE: 0.6614456544927189

# %%
k_prec = {}
k_rec = {}

for k in range(0, 200):
    precisions, recalls = precision_recall_at_k_4df(df_test, k=k, threshold=3) 
    p_mean = np.mean(list(precisions.values()))
    r_mean = np.mean(list(recalls.values()))
    k_prec[k] = p_mean
    k_rec[k] = r_mean

# %%
row = XPRow(dataset='Toys and Games', xpdata=XPData(predictor=None, label='CDL-SDAE-SGD', nfactors=25), rmse=mse, mae=mae, precision=k_prec, recall=k_rec)

# %%
write_to_csv(row, 'sdae_sgd_optimized4')

# %% [markdown]
# ## Optimization

# %%
if not os.path.isdir('./optimiz/'):
    os.mkdir('./optimiz/')
    
# %reset Out
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y
# Flushing output cache (12 entries)

# %%
params = {
    "hidden_size": [100, 150],
    "k": [25, 50],
    "matrix_noise": [0.3],
    "drop_ratio": [0.1],
    "lambda_q": [1, 10, 100],
    "lambda_v": [0.1, 1],
    "lambda_w": [1],
    "lambda_n": [10, 100]
}

# k=50, hidden_size=150, matrix_noise=0.3, drop_ratio=0.1, 
# lambda_w=20, lambda_v=100, lambda_n=10, lambda_q = 0.01

# %%
sorted_keys = sorted(params)
combinations = list(it.product(*(params[key] for key in sorted_keys)))

# %%
print("Num of combinations: %s" % len(combinations))
# Out:
# Num of combinations: 48

# %%
# write header row
write_row('./optimiz/cdl_sdae_sgd_5.csv', sorted_keys + ['rmse_train', 'mae_train', 'rmse_test', 'mae_test'])

# %%
for ps in combinations:
    tf.reset_default_graph()
    hyper_params = dict(zip(sorted_keys, ps))
    
    print("Start testing hyper params: ", hyper_params)
    cdl = CDL(dataset.values, testset.values, item_infomation_matrix,
              n_users=len(reviewers_map), n_items=len(asins_map),
              out_path=None, epochs=50, **hyper_params)
    
    mu, pu, qi, bu, bi = cdl.training() #188910
    
    preds = mf_sgd.SGD.predict_dataset_with_params(dataset.values, mu, bu, bi, qi, pu)
    train_rmse = mean_squared_error(df_train.overall, preds) ** 0.5
    train_mae = mean_absolute_error(df_train.overall, preds)
    print("MSE (non zero, train set): %s" % train_rmse)
    print("MAE (non zero, train set): %s" % train_mae)
    
    preds = mf_sgd.SGD.predict_dataset_with_params(testset.values, mu, bu, bi, qi, pu)
    test_rmse = mean_squared_error(df_test.overall, preds) ** 0.5
    test_mae = mean_absolute_error(df_test.overall, preds)
    print("MSE (test set): %s" % test_rmse)
    print("MAE (test set): %s" % test_mae)
    
    print("Stop testing hyper params: ", hyper_params)
    
    # write to file
    write_row('./optimiz/cdl_sdae_sgd_5.csv', [hyper_params[k] for k in sorted_keys] + [train_rmse, train_mae, test_rmse, test_mae] )
# Out:
# Start testing hyper params:  {'k': 25, 'lambda_v': 0.1, 'lambda_n': 10, 'drop_ratio': 0.1, 'hidden_size': 100, 'lambda_q': 1, 'matrix_noise': 0.3, 'lambda_w': 1}
# Mask shape: (10668, 10000)
# Noising completed..:(10668, 10000)
# EPOCH 1 / 50
# Running SGD...
# ALS LOSS RMSE = 1.146258261541519, MAE = 0.8998693705933507
# MODEL LOSS 578.9956
# AUTOENCODER LOSS 140.20537
# VALIDATION LOSS 1.1578175818141412
# EPOCH 2 / 50
# Running SGD...
# ALS LOSS RMSE = 1.113357593106672, MAE = 0.8721600789981285
# MODEL LOSS 138.97192
# AUTOENCODER LOSS 136.30075
# VALIDATION LOSS 1.1346009947588271
# EPOCH 3 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0892960046037186, MAE = 0.851714444789876
# MODEL LOSS 138.12167
# AUTOENCODER LOSS 136.357
# VALIDATION LOSS 1.1191726398161224
# EPOCH 4 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0700055683768157, MAE = 0.8353285029059948
# MODEL LOSS 138.07527
# AUTOENCODER LOSS 136.34114
# VALIDATION LOSS 1.1076883180561743
# EPOCH 5 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0537868619558617, MAE = 0.821493072049333
# MODEL LOSS 138.08902
# AUTOENCODER LOSS 136.37462
# VALIDATION LOSS 1.0986520047508126
# EPOCH 6 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0397641271256237, MAE = 0.8094821578552639
# MODEL LOSS 137.98837
# AUTOENCODER LOSS 136.26831
# VALIDATION LOSS 1.091285187768537
# EPOCH 7 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0274176859229933, MAE = 0.798847470120004
# MODEL LOSS 137.94623
# AUTOENCODER LOSS 136.21918
# VALIDATION LOSS 1.0851368591687471
# EPOCH 8 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0163897762164578, MAE = 0.7892887586312071
# MODEL LOSS 137.93031
# AUTOENCODER LOSS 136.19844
# VALIDATION LOSS 1.0799277950892943
# EPOCH 9 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0064499236185773, MAE = 0.7806031130349993
# MODEL LOSS 138.00298
# AUTOENCODER LOSS 136.25903
# VALIDATION LOSS 1.0754671961161362
# EPOCH 10 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9974240145634612, MAE = 0.7726625235346241
# MODEL LOSS 137.91466
# AUTOENCODER LOSS 136.1477
# VALIDATION LOSS 1.0716095455605832
# EPOCH 11 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9891552478304307, MAE = 0.7653277423716991
# MODEL LOSS 137.98074
# AUTOENCODER LOSS 136.16118
# VALIDATION LOSS 1.0682534446354746
# EPOCH 12 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9815573949876177, MAE = 0.7585358283817744
# MODEL LOSS 137.8811
# AUTOENCODER LOSS 136.01219
# VALIDATION LOSS 1.0653290789542258
# EPOCH 13 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9745382344388359, MAE = 0.7522125734028474
# MODEL LOSS 137.93782
# AUTOENCODER LOSS 136.03264
# VALIDATION LOSS 1.0627491093150097
# EPOCH 14 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9680118539549739, MAE = 0.7462887285157751
# MODEL LOSS 137.90031
# AUTOENCODER LOSS 135.9861
# VALIDATION LOSS 1.0604865842815185
# EPOCH 15 / 50
# Running SGD...
# ALS LOSS RMSE = 0.
# EPOCH 23 / 50
# Running SGD...
# ALS LOSS RMSE = 0.937213393903126, MAE = 0.7153039666873204
# MODEL LOSS 137.60573
# AUTOENCODER LOSS 136.0316
# VALIDATION LOSS 1.048830384467077
# EPOCH 24 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9340247629701329, MAE = 0.7122335630863124
# MODEL LOSS 137.61118
# AUTOENCODER LOSS 136.05455
# VALIDATION LOSS 1.0482720535102328
# EPOCH 25 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9310322668739477, MAE = 0.7093574015200841
# MODEL LOSS 137.51895
# AUTOENCODER LOSS 135.94293
# VALIDATION LOSS 1.0477569154249022
# EPOCH 26 / 50
# Running SGD...
# ALS LOSS RMSE = 0.928077570109014, MAE = 0.70650807943431
# MODEL LOSS 137.5351
# AUTOENCODER LOSS 135.92497
# VALIDATION LOSS 1.0474036697127136
# EPOCH 27 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9252831918482782, MAE = 0.7038017778450443
# MODEL LOSS 137.64119
# AUTOENCODER LOSS 136.03033
# VALIDATION LOSS 1.0470845418529917
# EPOCH 28 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9227364320984257, MAE = 0.7013294593052778
# MODEL LOSS 137.51595
# AUTOENCODER LOSS 135.92892
# VALIDATION LOSS 1.046803096988714
# EPOCH 29 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9200520878713129, MAE = 0.698739250835318
# MODEL LOSS 137.58728
# AUTOENCODER LOSS 135.95071
# VALIDATION LOSS 1.0466282802076683
# EPOCH 30 / 50
# Running SGD...
# ALS LOSS RMSE = 0.917773271871637, MAE = 0.6965352814763861
# MODEL LOSS 137.62733
# AUTOENCODER LOSS 135.98857
# VALIDATION LOSS 1.046433039101694
# EPOCH 31 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9156192496757051, MAE = 0.6944385434633662
# MODEL LOSS 137.57265
# AUTOENCODER LOSS 135.95901
# VALIDATION LOSS 1.0463241483234358
# EPOCH 32 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9134049116896787, MAE = 0.6922932609420565
# MODEL LOSS 137.54341
# AUTOENCODER LOSS 135.92142
# VALIDATION LOSS 1.0462761402259502
# EPOCH 33 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9114958112202258, MAE = 0.690441252404026
# MODEL LOSS 137.62267
# AUTOENCODER LOSS 135.99435
# VALIDATION LOSS 1.046274848713618
# EPOCH 34 / 50
# Running SGD...
# ALS LOSS RMSE = 0.909552774558568, MAE = 0.6885569449948757
# MODEL LOSS 137.59515
# AUTOENCODER LOSS 135.9408
# VALIDATION LOSS 1.046323873430288
# EPOCH 35 / 50
# Running SGD...
# Stopping early because 1.0463686295369399 is larger than [1.0462761402259502, 1.046274848713618, 1.046323873430288]
# MSE (non zero, train set): 0.9077482498491423
# MAE (non zero, train set): 0.6867824694486159
# MSE (test set): 1.0463686295369399
# MAE (test set): 0.7924410631917218
# Stop testing hyper params:  {'k': 25, 'lambda_v': 1, 'lambda_n': 10, 'drop_ratio': 0.1, 'hidden_size': 100, 'lambda_q': 10, 'matrix_noise': 0.3, 'lambda_w': 1}
# Start testing hyper params:  {'k': 25, 'lambda_v': 0.1, 'lambda_n': 10, 'drop_ratio': 0.1, 'hidden_size': 100, 'lambda_q': 100, 'matrix_noise': 0.3, 'lambda_w': 1}
# Mask shape: (10668, 10000)
# Noising completed..:(10668, 10000)
# EPOCH 1 / 50
# Running SGD...
# ALS LOSS RMSE = 1.1478858495734077, MAE = 0.9008543502169863
# MODEL LOSS 578.5723
# AUTOENCODER LOSS 138.50299
# VALIDATION LOSS 1.1571349764718966
# EPOCH 2 / 50
# Running SGD...
# ALS LOSS RMSE = 1.116630970355986, MAE = 0.8743806103582835
# MODEL LOSS 138.3952
# AUTOENCODER LOSS 135.8535
# VALIDATION LOSS 1.1339583463383707
# EPOCH 3 / 50
# Running SGD...
# ALS LOSS RMSE = 1.093633574969556, MAE = 0.8548237534735782
# MODEL LOSS 137.51085
# AUTOENCODER LOSS 135.9401
# VALIDATION LOSS 1.1184340051603314
# EPOCH 4 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0752360769788873, MAE = 0.8391137980556306
# MODEL LOSS 137.50043
# AUTOENCODER LOSS 135.97227
# VALIDATION LOSS 1.1069304110844889
# EPOCH 5 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0597187773801076, MAE = 0.8258361958377487
# MODEL LOSS 137.47227
# AUTOENCODER LOSS 135.92287
# VALIDATION LOSS 1.0978162849417126
# EPOCH 6 / 50
# Running SGD...
# ALS LOSS RMSE = 1.
# EPOCH 21 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9361470809484538, MAE = 0.7154471477994323
# MODEL LOSS 1294.9354
# AUTOENCODER LOSS 1250.232
# VALIDATION LOSS 1.0505086537562518
# EPOCH 22 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9319771477221863, MAE = 0.7114955551587704
# MODEL LOSS 1294.1903
# AUTOENCODER LOSS 1249.1868
# VALIDATION LOSS 1.0497742570076487
# EPOCH 23 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9279704797731583, MAE = 0.7077236443321204
# MODEL LOSS 1296.2523
# AUTOENCODER LOSS 1250.3943
# VALIDATION LOSS 1.0491366875264099
# EPOCH 24 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9242581274851536, MAE = 0.7042560950412915
# MODEL LOSS 1293.3196
# AUTOENCODER LOSS 1247.4156
# VALIDATION LOSS 1.0486154494807727
# EPOCH 25 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9208386886652087, MAE = 0.7010024322072603
# MODEL LOSS 1293.5461
# AUTOENCODER LOSS 1246.9042
# VALIDATION LOSS 1.0481657223077916
# EPOCH 26 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9175898197986488, MAE = 0.6979508291136122
# MODEL LOSS 1291.6233
# AUTOENCODER LOSS 1244.4519
# VALIDATION LOSS 1.0478693327758268
# EPOCH 27 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9145513561570358, MAE = 0.6951062455814103
# MODEL LOSS 1291.7081
# AUTOENCODER LOSS 1244.3275
# VALIDATION LOSS 1.0474895442140957
# EPOCH 28 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9115653135683365, MAE = 0.6922630243888368
# MODEL LOSS 1290.194
# AUTOENCODER LOSS 1242.125
# VALIDATION LOSS 1.0473568329522207
# EPOCH 29 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9087438810275342, MAE = 0.6896242823573131
# MODEL LOSS 1290.8528
# AUTOENCODER LOSS 1242.1802
# VALIDATION LOSS 1.0472287544545844
# EPOCH 30 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9062408035125615, MAE = 0.6872434480374656
# MODEL LOSS 1290.6324
# AUTOENCODER LOSS 1241.6012
# VALIDATION LOSS 1.0470463356779587
# EPOCH 31 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9032905871088085, MAE = 0.6845104766740712
# MODEL LOSS 1289.62
# AUTOENCODER LOSS 1240.1289
# VALIDATION LOSS 1.0470634276220188
# EPOCH 32 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9010238989815024, MAE = 0.682349775084768
# MODEL LOSS 1289.0457
# AUTOENCODER LOSS 1239.2832
# VALIDATION LOSS 1.0469619238195949
# EPOCH 33 / 50
# Running SGD...
# ALS LOSS RMSE = 0.8986587949181916, MAE = 0.6801483819560654
# MODEL LOSS 1290.8065
# AUTOENCODER LOSS 1240.6453
# VALIDATION LOSS 1.046992597980372
# EPOCH 34 / 50
# Running SGD...
# Stopping early because 1.0471629108633203 is larger than [1.0470634276220188, 1.0469619238195949, 1.046992597980372]
# MSE (non zero, train set): 0.8961842989803985
# MAE (non zero, train set): 0.6778582814167673
# MSE (test set): 1.0471629108633203
# MAE (test set): 0.7930400071438807
# Stop testing hyper params:  {'k': 50, 'lambda_v': 1, 'lambda_n': 100, 'drop_ratio': 0.1, 'hidden_size': 150, 'lambda_q': 10, 'matrix_noise': 0.3, 'lambda_w': 1}
# Start testing hyper params:  {'k': 50, 'lambda_v': 0.1, 'lambda_n': 100, 'drop_ratio': 0.1, 'hidden_size': 150, 'lambda_q': 100, 'matrix_noise': 0.3, 'lambda_w': 1}
# Mask shape: (10668, 10000)
# Noising completed..:(10668, 10000)
# EPOCH 1 / 50
# Running SGD...
# ALS LOSS RMSE = 1.147680640776724, MAE = 0.9007024798285317
# MODEL LOSS 1758.5807
# AUTOENCODER LOSS 1369.9197
# VALIDATION LOSS 1.1571190484521605
# EPOCH 2 / 50
# Running SGD...
# ALS LOSS RMSE = 1.116416062294892, MAE = 0.8741993073502679
# MODEL LOSS 1344.7612
# AUTOENCODER LOSS 1322.4946
# VALIDATION LOSS 1.133911841508022
# EPOCH 3 / 50
# Running SGD...
# ALS LOSS RMSE = 1.
# EPOCH 23 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9281132079519661, MAE = 0.7075213623282269
# MODEL LOSS 1292.947
# AUTOENCODER LOSS 1246.7009
# VALIDATION LOSS 1.049188578195457
# EPOCH 24 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9241950670276315, MAE = 0.7037965616393417
# MODEL LOSS 1292.2617
# AUTOENCODER LOSS 1244.7745
# VALIDATION LOSS 1.0486275792246453
# EPOCH 25 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9205875205087984, MAE = 0.7004229542829459
# MODEL LOSS 1288.87
# AUTOENCODER LOSS 1240.9288
# VALIDATION LOSS 1.0483758311365696
# EPOCH 26 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9171284006251199, MAE = 0.6971713930941549
# MODEL LOSS 1286.954
# AUTOENCODER LOSS 1238.5615
# VALIDATION LOSS 1.0479413006426261
# EPOCH 27 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9143637790966711, MAE = 0.6946420618753133
# MODEL LOSS 1287.9578
# AUTOENCODER LOSS 1239.0869
# VALIDATION LOSS 1.0475860587696033
# EPOCH 28 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9111719038102256, MAE = 0.6915911913110792
# MODEL LOSS 1285.5562
# AUTOENCODER LOSS 1236.4272
# VALIDATION LOSS 1.0474567515153628
# EPOCH 29 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9081734126981981, MAE = 0.6887683028516073
# MODEL LOSS 1282.8633
# AUTOENCODER LOSS 1233.1727
# VALIDATION LOSS 1.0473889316430989
# EPOCH 30 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9055324886164664, MAE = 0.6862664809134248
# MODEL LOSS 1283.9747
# AUTOENCODER LOSS 1233.3981
# VALIDATION LOSS 1.0472643718698165
# EPOCH 31 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9025761010348998, MAE = 0.6835927431432057
# MODEL LOSS 1283.1104
# AUTOENCODER LOSS 1232.4983
# VALIDATION LOSS 1.0471451934706786
# EPOCH 32 / 50
# Running SGD...
# ALS LOSS RMSE = 0.900606232767466, MAE = 0.6816555008967877
# MODEL LOSS 1281.5302
# AUTOENCODER LOSS 1230.5526
# VALIDATION LOSS 1.0472516290928338
# EPOCH 33 / 50
# Running SGD...
# Stopping early because 1.0473661522729767 is larger than [1.0472643718698165, 1.0471451934706786, 1.0472516290928338]
# MSE (non zero, train set): 0.8974721876627028
# MAE (non zero, train set): 0.6788326486944367
# MSE (test set): 1.0473661522729767
# MAE (test set): 0.7932096874675142
# Stop testing hyper params:  {'k': 50, 'lambda_v': 0.1, 'lambda_n': 100, 'drop_ratio': 0.1, 'hidden_size': 150, 'lambda_q': 100, 'matrix_noise': 0.3, 'lambda_w': 1}
# Start testing hyper params:  {'k': 50, 'lambda_v': 1, 'lambda_n': 100, 'drop_ratio': 0.1, 'hidden_size': 150, 'lambda_q': 100, 'matrix_noise': 0.3, 'lambda_w': 1}
# Mask shape: (10668, 10000)
# Noising completed..:(10668, 10000)
# EPOCH 1 / 50
# Running SGD...
# ALS LOSS RMSE = 1.1476880906203097, MAE = 0.9007152601822316
# MODEL LOSS 1759.7543
# AUTOENCODER LOSS 1372.511
# VALIDATION LOSS 1.1571386906530094
# EPOCH 2 / 50
# Running SGD...
# ALS LOSS RMSE = 1.1164613548277282, MAE = 0.8742652915558893
# MODEL LOSS 1347.0471
# AUTOENCODER LOSS 1326.7213
# VALIDATION LOSS 1.1338873495789095
# EPOCH 3 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0935799368303187, MAE = 0.8547492056645462
# MODEL LOSS 1335.0071
# AUTOENCODER LOSS 1313.6809
# VALIDATION LOSS 1.1185147876134518
# EPOCH 4 / 50
# Running SGD...
# ALS LOSS RMSE = 1.075074922915966, MAE = 0.8389666310179634
# MODEL LOSS 1330.1759
# AUTOENCODER LOSS 1306.3573
# VALIDATION LOSS 1.1070528007375469
# EPOCH 5 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0593751810838734, MAE = 0.8255456173204062
# MODEL LOSS 1326.6035
# AUTOENCODER LOSS 1300.1637
# VALIDATION LOSS 1.097971552396241
# EPOCH 6 / 50
# Running SGD...
# ALS LOSS RMSE = 1.045689031754861, MAE = 0.8137906579790559
# MODEL LOSS 1323.099
# AUTOENCODER LOSS 1294.5962
# VALIDATION LOSS 1.0904598362098201
# EPOCH 7 / 50
# Running SGD...
# ALS LOSS RMSE = 1.033660926568758, MAE = 0.8033878732671011
# MODEL LOSS 1318.4441
# AUTOENCODER LOSS 1288.2522
# VALIDATION LOSS 1.0843241823276453
# EPOCH 8 / 50
# Running SGD...
# ALS LOSS RMSE = 1.022706216534726, MAE = 0.7938403570285738
# MODEL LOSS 1316.1454
# AUTOENCODER LOSS 1284.83
# VALIDATION LOSS 1.0790059413881357
# EPOCH 9 / 50
# Running SGD...
# ALS LOSS RMSE = 1.0129189468037176, MAE = 0.7852363330605859
# MODEL LOSS 1313.5822
# AUTOENCODER LOSS 1281.19
# VALIDATION LOSS 1.0745241303416522
# EPOCH 10 / 50
# Running SGD...
# ALS LOSS RMSE = 1.003883884294794, MAE = 0.777241238374595
# MODEL LOSS 1312.5017
# AUTOENCODER LOSS 1279.3381
# VALIDATION LOSS 1.0707240506292657
# EPOCH 11 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9957363523010062, MAE = 0.7699373659529645
# MODEL LOSS 1308.7014
# AUTOENCODER LOSS 1274.233
# VALIDATION LOSS 1.0673351601080383
# EPOCH 12 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9879742798037567, MAE = 0.7629415956020245
# MODEL LOSS 1306.6422
# AUTOENCODER LOSS 1270.8954
# VALIDATION LOSS 1.0644801112654063
# EPOCH 13 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9808037400341356, MAE = 0.7564711542628496
# MODEL LOSS 1305.5808
# AUTOENCODER LOSS 1268.9594
# VALIDATION LOSS 1.0618777866573141
# EPOCH 14 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9742631884753289, MAE = 0.7504438716741422
# MODEL LOSS 1303.9082
# AUTOENCODER LOSS 1266.456
# VALIDATION LOSS 1.059586022321607
# EPOCH 15 / 50
# Running SGD...
# ALS LOSS RMSE = 0.968136699630696, MAE = 0.7448143453563285
# MODEL LOSS 1303.473
# AUTOENCODER LOSS 1265.1653
# VALIDATION LOSS 1.057673709899657
# EPOCH 16 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9624243116060952, MAE = 0.739491245216623
# MODEL LOSS 1301.4021
# AUTOENCODER LOSS 1262.4329
# VALIDATION LOSS 1.0559807615978507
# EPOCH 17 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9568283894379189, MAE = 0.7343324124532351
# MODEL LOSS 1299.5577
# AUTOENCODER LOSS 1259.4641
# VALIDATION LOSS 1.0544201180368253
# EPOCH 18 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9518439387187837, MAE = 0.7296603150454323
# MODEL LOSS 1298.036
# AUTOENCODER LOSS 1257.1749
# VALIDATION LOSS 1.0532031825115074
# EPOCH 19 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9469473523439157, MAE = 0.7250310902775543
# MODEL LOSS 1295.9974
# AUTOENCODER LOSS 1254.2571
# VALIDATION LOSS 1.0520402046732755
# EPOCH 20 / 50
# Running SGD...
# ALS LOSS RMSE = 0.942433038284237, MAE = 0.7208432546803168
# MODEL LOSS 1296.4106
# AUTOENCODER LOSS 1254.1293
# VALIDATION LOSS 1.05097832117327
# EPOCH 21 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9382278790428531, MAE = 0.7168506715944138
# MODEL LOSS 1295.8203
# AUTOENCODER LOSS 1253.1134
# VALIDATION LOSS 1.050123807057764
# EPOCH 22 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9341969323568363, MAE = 0.7131161183860923
# MODEL LOSS 1293.9341
# AUTOENCODER LOSS 1250.77
# VALIDATION LOSS 1.049606800398491
# EPOCH 23 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9304944964057464, MAE = 0.7096003547025475
# MODEL LOSS 1291.4465
# AUTOENCODER LOSS 1248.3416
# VALIDATION LOSS 1.0487974209726074
# EPOCH 24 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9271119941367024, MAE = 0.7063895801818664
# MODEL LOSS 1291.4161
# AUTOENCODER LOSS 1247.7938
# VALIDATION LOSS 1.0482130208612233
# EPOCH 25 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9234927628560298, MAE = 0.7029658609132129
# MODEL LOSS 1290.5166
# AUTOENCODER LOSS 1246.6421
# VALIDATION LOSS 1.0478442350552606
# EPOCH 26 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9201949667670831, MAE = 0.6998909045214695
# MODEL LOSS 1288.7909
# AUTOENCODER LOSS 1244.3524
# VALIDATION LOSS 1.0475402850382949
# EPOCH 27 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9173915679702281, MAE = 0.6972303625943991
# MODEL LOSS 1287.5892
# AUTOENCODER LOSS 1242.7408
# VALIDATION LOSS 1.0473151582097062
# EPOCH 28 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9141539443807607, MAE = 0.6941473108641758
# MODEL LOSS 1288.019
# AUTOENCODER LOSS 1242.4639
# VALIDATION LOSS 1.047008637912526
# EPOCH 29 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9110976610682282, MAE = 0.6913398558253646
# MODEL LOSS 1286.1276
# AUTOENCODER LOSS 1239.9727
# VALIDATION LOSS 1.0468899336493291
# EPOCH 30 / 50
# Running SGD...
# ALS LOSS RMSE = 0.908828304802648, MAE = 0.6891349696405844
# MODEL LOSS 1286.3722
# AUTOENCODER LOSS 1239.5358
# VALIDATION LOSS 1.0468467866445452
# EPOCH 31 / 50
# Running SGD...
# ALS LOSS RMSE = 0.90569005812103, MAE = 0.6862125216876748
# MODEL LOSS 1284.2646
# AUTOENCODER LOSS 1236.769
# VALIDATION LOSS 1.0467936547780028
# EPOCH 32 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9034767183951081, MAE = 0.6840712642051957
# MODEL LOSS 1284.731
# AUTOENCODER LOSS 1236.8455
# VALIDATION LOSS 1.0468765235054474
# EPOCH 33 / 50
# Running SGD...
# ALS LOSS RMSE = 0.9009538692468587, MAE = 0.681725490393157
# MODEL LOSS 1283.1293
# AUTOENCODER LOSS 1234.6176
# VALIDATION LOSS 1.0466413754718225
# EPOCH 34 / 50
# Running SGD...
# Stopping early because 1.0469056006793696 is larger than [1.0467936547780028, 1.0468765235054474, 1.0466413754718225]
# MSE (non zero, train set): 0.8986858413062162
# MAE (non zero, train set): 0.6795633434510303
# MSE (test set): 1.0469056006793696
# MAE (test set): 0.7926909689688312
# Stop testing hyper params:  {'k': 50, 'lambda_v': 1, 'lambda_n': 100, 'drop_ratio': 0.1, 'hidden_size': 150, 'lambda_q': 100, 'matrix_noise': 0.3, 'lambda_w': 1}
